# %%
import os, sys, gc, subprocess  
os.chdir('../')
# print(sys.path)
# print(subprocess.check_output('pwd',shell=True, universal_newlines=True))

# %%
# import load_path
import config, data, model, util                                                
from datetime import datetime                                                   
from obspy.clients.fdsn import Client                                           
import obspy.core as oc

# %% [markdown]
# ## 1. Configure DPP

# %%
# config
#
util.init_session()
dpp_config = config.Config()
# dpp_config.set_trigger(pthres_p=[0.9, 0.001], pthres_s=[0.9, 0.001])
dpp_config.set_trigger(pthres_p=[0.95, 0.001], pthres_s=[0.9, 0.001])
# dpp_config.set_picking(op_conds=['1','2','3','4'], tp_th_add=1.5, dt_sp_near=1.5, dt_ps_max=25., dt_sdup_max=2., mcd_iter=10, run_mcd=True)
dpp_config.set_picking(op_conds=['1','2','3','4'], tp_th_add=1.5, dt_sp_near=1.5, dt_ps_max=25., dt_sdup_max=2., run_mcd=False)
# dpp_config.set_picking(op_conds=[], tp_th_add=1.5, dt_sp_near=1.5, dt_ps_max=25., dt_sdup_max=2., mcd_iter=10, run_mcd=False)
dpp_config.set_data(
    stas=['PB01', 'PB02'],
    net='CX',
    ch='HH',
    archive='archive_CX_20140701_test',
    opath='out_CX_20140701_test'
)
dpp_config.set_time(
    dt_iter=3600.,
    #
#     tstart = "2014-05-01T00:00:00",
#     tend = "2014-05-01T06:00:00",
    #
#     tstart = "2014-06-01T00:00:00",
#     tend = "2014-06-01T06:00:00",     
    #
    tstart = "2014-07-01T00:00:00",
    tend = "2014-07-01T06:00:00",         
)
# Out:
# __pycache__/ removed
# ~/.nv/ not found, continuing...

# %% [markdown]
# ## 2. Download seismic data and read it into DPP

# %%
# download and archive seismic waveforms
#
client = Client("GFZ")
os.makedirs(f"{dpp_config.data['archive']}", exist_ok=True)
tstart = oc.UTCDateTime(dpp_config.time['tstart'])
tend = oc.UTCDateTime(dpp_config.time['tend'])
# tstart = oc.UTCDateTime(dpp_config.time['tstart']) - 500
# tend = oc.UTCDateTime(dpp_config.time['tstart']) + 600
for sta in dpp_config.data['stas']:
    st = client.get_waveforms(network=dpp_config.data['net'], station=sta, location="*", channel=f"{dpp_config.data['ch']}?", starttime=tstart, endtime=tend)
    # print(st)
    st_name = f"{dpp_config.data['archive']}/{st[0].stats.network}.{st[0].stats.station}..{st[0].stats.channel[:-1]}.mseed"
    print(f"writing stream {st_name}...")
    st.write(st_name, format="MSEED")
# Out:
# writing stream archive_CX_20140601_test/CX.PB01..HH.mseed...
# writing stream archive_CX_20140601_test/CX.PB02..HH.mseed...

# %%
# data
#
dpp_data = data.Data()
dpp_data.read_from_directory(dpp_config)
#
# for k in dpp_data.data:
#     print(k, dpp_data.data[k])
# Out:
# reading seismic waveform: archive_CX_20140601_test/CX.PB01..HH.mseed
# reading seismic waveform: archive_CX_20140601_test/CX.PB02..HH.mseed
# 6 Trace(s) in Stream:
# CX.PB01..HHZ | 2014-05-31T23:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 2160001 samples
# CX.PB01..HHE | 2014-05-31T23:59:59.998394Z - 2014-06-01T05:59:59.998394Z | 100.0 Hz, 2160001 samples
# CX.PB01..HHN | 2014-05-31T23:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 2160001 samples
# CX.PB02..HHZ | 2014-05-31T23:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 2160001 samples
# CX.PB02..HHE | 2014-05-31T23:59:59.998391Z - 2014-06-01T05:59:59.998391Z | 100.0 Hz, 2160001 samples
# CX.PB02..HHN | 2014-05-31T23:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 2160001 samples
# #
# processing raw stream data...
# detrend...
# resampling...
# merging...
# #
# time windows (6) for iteration over continuous waveforms:
# [UTCDateTime(2014, 6, 1, 0, 0), UTCDateTime(2014, 6, 1, 1, 0)]
# [UTCDateTime(2014, 6, 1, 1, 0), UTCDateTime(2014, 6, 1, 2, 0)]
# [UTCDateTime(2014, 6, 1, 2, 0), UTCDateTime(2014, 6, 1, 3, 0)]
# [UTCDateTime(2014, 6, 1, 3, 0), UTCDateTime(2014, 6, 1, 4, 0)]
# [UTCDateTime(2014, 6, 1, 4, 0), UTCDateTime(2014, 6, 1, 5, 0)]
# [UTCDateTime(2014, 6, 1, 5, 0), UTCDateTime(2014, 6, 1, 6, 0)]
#
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...

# %% [markdown]
# ## 3. Run phase detection and picking

# %%
# model
#
dpp_model = model.Model(verbose=False)
#
print(dpp_model.model_detection['best_model'].summary())
print(dpp_model.model_picking_P['best_model'].summary())
print(dpp_model.model_picking_S['best_model'].summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv1d_1 (Separabl (None, 480, 12)           99
# _________________________________________________________________
# activation_1 (Activation)    (None, 480, 12)           0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 480, 12)           48
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 240, 12)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 240, 12)           0
# _________________________________________________________________
# separable_conv1d_2 (Separabl (None, 240, 24)           444
# _________________________________________________________________
# activation_2 (Activation)    (None, 240, 24)           0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 240, 24)           96
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 120, 24)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120, 24)           0
# _________________________________________________________________
# separable_conv1d_3 (Separabl (None, 120, 48)           1320
# _________________________________________________________________
# activation_3 (Activation)    (None, 120, 48)           0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 120, 48)           192
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 60, 48)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 48)            0
# _________________________________________________________________
# separable_conv1d_4 (Separabl (None, 60, 96)            5136
# _________________________________________________________________
# activation_4 (Activation)    (None, 60, 96)            0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 60, 96)            384
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 30, 96)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 96)            0
# _________________________________________________________________
# separable_conv1d_5 (Separabl (None, 30, 192)           20256
# _________________________________________________________________
# activation_5 (Activation)    (None, 30, 192)           0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 30, 192)           768
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 15, 192)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 192)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 2880)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                144050
# _________________________________________________________________
# activation_6 (Activation)    (None, 50)                0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 50)                200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 153
# _________________________________________________________________
# activation_7 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 173,146
# Trainable params: 172,302
# Non-trainable params: 844
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 1)]          0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 480, 200)          81600
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 480, 320)          462080
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 480, 1)            321
# =================================================================
# Total params: 544,001
# Trainable params: 544,001
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 2)]          0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 480, 40)           3680
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 480, 60)           17040
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 480, 1)            61
# =================================================================
# Total params: 20,781
# Trainable params: 20,781
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# run phase detection
dpp_model.run_detection(dpp_config, dpp_data, save_dets=False, save_data=False)
# Out:
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 26s 36ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-31T23:59:59.998394Z - 2014-06-01T00:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-31T23:59:59.998393Z - 2014-06-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-31T23:59:59.998393Z - 2014-06-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 16, s_picks = 3
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 27s 37ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-31T23:59:59.998391Z - 2014-06-01T00:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-31T23:59:59.998393Z - 2014-06-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-31T23:59:59.998393Z - 2014-06-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 13, s_picks = 6
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 28s 39ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-06-01T00:59:59.998394Z - 2014-06-01T01:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-06-01T00:59:59.998393Z - 2014-06-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-06-01T00:59:59.998393Z - 2014-06-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 16, s_picks = 6
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 28s 38ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-06-01T00:59:59.998391Z - 2014-06-01T01:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-06-01T00:59:59.998393Z - 2014-06-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-06-01T00:59:59.998393Z - 2014-06-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 11, s_picks = 4
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 29s 40ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-06-01T01:59:59.998394Z - 2014-06-01T02:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-06-01T01:59:59.998393Z - 2014-06-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-06-01T01:59:59.998393Z - 2014-06-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 12, s_picks = 9
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 28s 39ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-06-01T01:59:59.998391Z - 2014-06-01T02:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-06-01T01:59:59.998393Z - 2014-06-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-06-01T01:59:59.998393Z - 2014-06-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 11, s_picks = 6
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 23s 32ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-06-01T02:59:59.998394Z - 2014-06-01T03:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-06-01T02:59:59.998393Z - 2014-06-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-06-01T02:59:59.998393Z - 2014-06-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 3, s_picks = 2
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 30s 41ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-06-01T02:59:59.998391Z - 2014-06-01T03:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-06-01T02:59:59.998393Z - 2014-06-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-06-01T02:59:59.998393Z - 2014-06-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 2, s_picks = 0
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 40s 56ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-06-01T03:59:59.998394Z - 2014-06-01T04:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-06-01T03:59:59.998393Z - 2014-06-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-06-01T03:59:59.998393Z - 2014-06-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 13, s_picks = 5
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 34s 48ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-06-01T03:59:59.998391Z - 2014-06-01T04:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-06-01T03:59:59.998393Z - 2014-06-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-06-01T03:59:59.998393Z - 2014-06-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 14, s_picks = 6
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 38s 53ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-06-01T04:59:59.998394Z - 2014-06-01T05:59:59.998394Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-06-01T04:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-06-01T04:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 12, s_picks = 6
# #
# Calculating predictions for stream: CX.PB02..HH?...
# strimming stream: 1, 1
# 720/720 [==============================] - 43s 59ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-06-01T04:59:59.998391Z - 2014-06-01T05:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-06-01T04:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-06-01T04:59:59.998393Z - 2014-06-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 7, s_picks = 4

# %%
# run phase picking
dpp_model.run_picking(dpp_config, dpp_data, save_plots=False, save_stats=True, save_picks=False)
# Out:
# ['PB01', 'PB02']
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 16, 16, 3, 3
# 1 0 1401582069.56
# 1 1 1401582109.36
# 1 2 1401582165.06
# 1 3 1401582193.76
# 1 4 1401582238.96
# 1 5 1401582450.76
# 1 6 1401582463.46
# 1 7 1401582939.56
# 1 8 1401583147.96
# 1 9 1401583413.56
# 1 10 1401583649.86
# 1 11 1401583817.86
# 1 12 1401583830.16
# 1 13 1401583912.46
# 1 14 1401584081.56
# 1 15 1401584280.16
# 4 0 1
# 4 1 2
# 2 0
# 2 1
# 3 0 1
# selected picks (P, S): 15, 1
# #
# 1 1401582069.56 True
# 2 1401582109.36 True
# 3 1401582165.06 True
# 4 1401582193.76 True
# 5 1401582238.96 True
# 6 1401582450.76 True
# 7 1401582463.46 False
# 8 1401582939.56 True
# 9 1401583147.96 True
# 10 1401583413.56 True
# 11 1401583649.86 True
# 12 1401583817.86 True
# 13 1401583830.16 True
# 14 1401583912.46 True
# 15 1401584081.56 True
# 16 1401584280.16 True
# #
# 1 1401582450.6 False
# 2 1401582463.5 True
# 3 1401584111.1 False
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 13, 13, 6, 6
# 1 0 1401582198.86
# 1 1 1401582227.06
# 1 2 1401582233.76
# 1 3 1401582453.86
# 1 4 1401582469.06
# 1 5 1401582861.46
# 1 6 1401583650.56
# 1 7 1401583725.96
# 1 8 1401583915.56
# 1 9 1401584085.16
# 1 10 1401584116.96
# 1 11 1401584284.36
# 1 12 1401584304.36
# 4 0 2
# 4 1 4
# 2 0
# 2 1
# 3 0 2
# selected picks (P, S): 11, 1
# #
# 1 1401582198.86 True
# 2 1401582227.06 True
# 3 1401582233.76 True
# 4 1401582453.86 True
# 5 1401582469.06 False
# 6 1401582861.46 True
# 7 1401583650.56 True
# 8 1401583725.96 True
# 9 1401583915.56 True
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0 0
# 3 1 2
# 3 2 6
# 3 3 8
# selected picks (P, S): 11, 4
# #
# 1 1401588312.46 True
# 2 1401588706.96 True
# 3 1401589703.26 True
# 4 1401589935.56 True
# 5 1401590079.76 True
# 6 1401590097.06 True
# 7 1401590291.96 True
# 8 1401590304.66 True
# 9 1401590769.86 True
# 10 1401590788.46 False
# 11 1401591184.86 True
# 12 1401591197.16 True
# #
# 1 1401588722.1 True
# 2 1401589935.4 False
# 3 1401589958.0 True
# 4 1401589964.4 False
# 5 1401590079.8 False
# 6 1401590097.1 False
# 7 1401590115.6 True
# 8 1401590769.9 False
# 9 1401590788.6 True
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 11, 11, 6, 6
# 1 0 1401588709.86
# 1 1 1401588727.16
# 1 2 1401589201.26
# 1 3 1401589617.36
# 1 4 1401589750.96
# 1 5 1401589934.06
# 1 6 1401590110.96
# 1 7 1401590311.46
# 1 8 1401590766.36
# 1 9 1401590842.96
# 1 10 1401591205.56
# 4 0 1
# 4 1 2
# 4 2 5
# 2 0
# 2 1
# 2 2
# 3 0 1
# 3 1 5
# selected picks (P, S): 11, 2
# #
# 1 1401588709.86 True
# 2 1401588727.16 True
# 3 1401589201.26 True
# 4 1401589617.36 True
# 5 1401589750.96 True
# 6 1401589934.06 True
# 7 1401590110.96 True
# 8 1401590311.46 True
# 9 1401590766.36 True
# 10 1401590842.96 True
# 11 1401591205.56 True
# #
# 1 1401588727.0 False
# 2 1401589955.5 True
# 3 1401589966.2 False
# 4 1401590110.9 False
# 5 1401590766.4 False
# 6 1401590781.5 True
# ['PB01', 'PB02']
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 3, 3, 2, 2
# 1 0 1401592083.06
# 1 1 1401593315.56
# 1 2 1401594733.26
# 4 0 0
# 4 1 1
# 2 0
# 2 1
# 3 0 0
# selected picks (P, S): 3, 1
# #
# 1 1401592083.06 True
# 2 1401593315.56 True
# 3 1401594733.26 True
# #
# 1 1401593333.3 True
# 2 1401593535.4 False
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 2, 2, 0, 0
# 1 0 1401593509.16
# 1 1 1401595121.96
# selected picks (P, S): 2, 0
# #
# 1 1401593509.16 True
# 2 1401595121.96 True
# #
# ['PB01', 'PB02']
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 13, 13, 5, 5
# 1 0 1401595572.16
# 1 1 1401595588.76
# 1 2 1401595731.46
# 1 3 1401596442.46
# 1 4 1401596472.76
# 1 5 1401597064.06
# 1 6 1401597201.16
# 1 7 1401597267.36
# 1 8 1401597513.16
# 1 9 1401597945.76
# 1 10 1401598166.86
# 1 11 1401598612.66
# 1 12 1401598780.26
# 4 0 0
# 4 1 1
# 4 2 3
# 2 0
# 2 1
# 2 2
# 3 0 0
# 3 1 3
# selected picks (P, S): 13, 2
# #
# 1 1401595572.16 True
# 2 1401595588.76 True
# 3 1401595731.46 True
# 4 1401596442.46 True
# 5 1401596472.76 True
# 6 1401597064.06 True
# 7 1401597201.16 True
# 8 1401597267.36 True
# 9 1401597513.16 True
# 10 1401597945.76 True
# 11 1401598166.86 True
# 12 1401598612.66 True
# 13 1401598780.26 True
# #
# 1 1401595749.8 True
# 2 1401597558.6 False
# 3 1401597946.1 False
# 4 1401597965.2 True
# 5 1401598780.4 False
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 14, 14, 6, 6
# 1 0 1401595594.06
# 1 1 1401595734.56
# 1 2 1401596477.96
# 1 3 1401597203.66
# 1 4 1401597513.76
# 1 5 1401597558.76
# 1 6 1401597943.86
# 1 7 1401598047.96
# 1 8 1401598085.76
# 1 9 1401598154.46
# 1 10 1401598160.86
# 1 11 1401598591.96
# 1 12 1401598778.86
# 1 13 1401598782.06
# 4 0 2
# 4 1 3
# 4 2 4
# 2 0
# 2 1
# 2 2
# 3 0 2
# selected picks (P, S): 14, 1
# #
# 1 1401595594.06 True
# 2 1401595734.56 True
# 3 1401596477.96 True
# 4 1401597203.66 True
# 5 1401597513.76 True
# 6 1401597558.76 True
# 7 1401597943.86 True
# 8 1401598047.96 True
# 9 1401598085.76 True
# 10 1401598154.46 True
# 11 1401598160.86 True
# 12 1401598591.96 True
# 13 1401598778.86 True
# 14 1401598782.06 True
# #
# 1 1401597514.1 False
# 2 1401597944.0 False
# 3 1401597963.5 True
# 4 1401597988.4 False
# 5 1401598027.9 False
# 6 1401598779.2 False
# ['PB01', 'PB02']
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 12, 12, 6, 6
# 1 0 1401598987.86
# 1 1 1401599156.16
# 1 2 1401599462.46
# 1 3 1401599512.86
# 1 4 1401599657.76
# 1 5 1401599777.16
# 1 6 1401600332.36
# 1 7 1401600348.96
# 1 8 1401600361.26
# 1 9 1401601027.36
# 1 10 1401601401.86
# 1 11 1401601975.26
# 4 0 0
# 4 1 1
# 4 2 3
# 4 3 4
# 4 4 5
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0 3
# 3 1 4
# 3 2 5
# selected picks (P, S): 11, 3
# #
# 1 1401598987.86 True
# 2 1401599156.16 True
# 3 1401599462.46 True
# 4 1401599512.86 True
# 5 1401599657.76 True
# 6 1401599777.16 True
# 7 1401600332.36 True
# 8 1401600348.96 False
# 9 1401600361.26 True
# 10 1401601027.36 True
# 11 1401601401.86 True
# 12 1401601975.26 True
# #
# 1 1401598806.5 False
# 2 1401599545.0 False
# 3 1401599657.9 False
# 4 1401600349.1 True
# 5 1401600379.6 True
# 6 1401601994.7 True
# #
# ['1', '2', '3', '4']
# detected picks (P, S): 7, 7, 4, 4
# 1 0 1401599009.96
# 1 1 1401599659.26
# 1 2 1401600208.56
# 1 3 1401600365.26
# 1 4 1401600860.86
# 1 5 1401601034.26
# 1 6 1401601973.56
