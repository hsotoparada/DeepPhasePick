# %% [markdown]
# ### This example applies DeepPhasePick on seismic data stored in a archive directory structured as: archive/YY/NET/STA/CH. <br><br> Here YY is year, NET is the network code, STA is the station code and CH is the channel code (e.g., HH) of the seismic streams.

# %%
import os
os.chdir('../')
import config, data, model, util

# %% [markdown]
# ## 1. Configure DPP

# %%
# config
util.init_session()
dpp_config = config.Config()
dpp_config.set_trigger(pthres_p=[0.9, 0.001], pthres_s=[0.9, 0.001])
# dpp_config.set_picking(mcd_iter=10, run_mcd=True)
dpp_config.set_picking(run_mcd=False)
#
dpp_config.set_data(
    stas=['PB01', 'PB02'],
    net='CX',
    ch='HH',
    archive='sample_data/archive',
    opath='out_archive'
)
dpp_config.set_time(
    dt_iter=3600.,
    #
    tstart = "2014-05-01T00:00:00",
    tend = "2014-05-01T12:00:00",    
)
# Out:
# __pycache__/ removed
# ~/.nv/ not found, continuing...

# %% [markdown]
# ## 2. Read seismic data into DPP

# %%
# data
dpp_data = data.Data()
dpp_data.read_from_archive(dpp_config)
#
for k in dpp_data.data:
    print(k, dpp_data.data[k])
# Out:
# #
# time windows (12) for iteration over continuous waveforms:
# [UTCDateTime(2014, 5, 1, 0, 0), UTCDateTime(2014, 5, 1, 1, 0)]
# [UTCDateTime(2014, 5, 1, 1, 0), UTCDateTime(2014, 5, 1, 2, 0)]
# [UTCDateTime(2014, 5, 1, 2, 0), UTCDateTime(2014, 5, 1, 3, 0)]
# [UTCDateTime(2014, 5, 1, 3, 0), UTCDateTime(2014, 5, 1, 4, 0)]
# [UTCDateTime(2014, 5, 1, 4, 0), UTCDateTime(2014, 5, 1, 5, 0)]
# [UTCDateTime(2014, 5, 1, 5, 0), UTCDateTime(2014, 5, 1, 6, 0)]
# [UTCDateTime(2014, 5, 1, 6, 0), UTCDateTime(2014, 5, 1, 7, 0)]
# [UTCDateTime(2014, 5, 1, 7, 0), UTCDateTime(2014, 5, 1, 8, 0)]
# [UTCDateTime(2014, 5, 1, 8, 0), UTCDateTime(2014, 5, 1, 9, 0)]
# [UTCDateTime(2014, 5, 1, 9, 0), UTCDateTime(2014, 5, 1, 10, 0)]
# [UTCDateTime(2014, 5, 1, 10, 0), UTCDateTime(2014, 5, 1, 11, 0)]
# [UTCDateTime(2014, 5, 1, 11, 0), UTCDateTime(2014, 5, 1, 12, 0)]
#
#
# retrieving seismic waveforms for stations:
# ['PB01', 'PB02']
# seismic data found for: net = CX, sta = PB01, st_count = 0, st_arg = 0
# ['sample_data/archive/2014/CX/PB01/HHE.D/CX.PB01..HHE.D.2014.121', 'sample_data/archive/2014/CX/PB01/HHZ.D/CX.PB01..HHZ.D.2014.121', 'sample_data/archive/2014/CX/PB01/HHN.D/CX.PB01..HHN.D.2014.121']
# sample_data/archive/2014/CX/PB01/HHE.D/CX.PB01..HHE.D.2014.121
# sample_data/archive/2014/CX/PB01/HHZ.D/CX.PB01..HHZ.D.2014.121
# sample_data/archive/2014/CX/PB01/HHN.D/CX.PB01..HHN.D.2014.121
# seismic data found for: net = CX, sta = PB02, st_count = 3, st_arg = 0
# ['sample_data/archive/2014/CX/PB02/HHE.D/CX.PB02..HHE.D.2014.121', 'sample_data/archive/2014/CX/PB02/HHZ.D/CX.PB02..HHZ.D.2014.121', 'sample_data/archive/2014/CX/PB02/HHN.D/CX.PB02..HHN.D.2014.121']
# sample_data/archive/2014/CX/PB02/HHE.D/CX.PB02..HHE.D.2014.121
# sample_data/archive/2014/CX/PB02/HHZ.D/CX.PB02..HHZ.D.2014.121
# sample_data/archive/2014/CX/PB02/HHN.D/CX.PB02..HHN.D.2014.121
# 6 Trace(s) in Stream:
# CX.PB01..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples
# CX.PB01..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples
# CX.PB01..HHN | 2014-04-30T23:59:59.998391Z - 2014-05-01T11:59:59.998391Z | 100.0 Hz, 4320001 samples
# CX.PB02..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples
# CX.PB02..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples
# CX.PB02..HHN | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples
# #
# processing raw stream data...
# detrend...
# resampling...
# CX.PB01..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# CX.PB01..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# CX.PB01..HHN | 2014-04-30T23:59:59.998391Z - 2014-05-01T11:59:59.998391Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# CX.PB02..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# CX.PB02..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# CX.PB02..HHN | 2014-04-30T23:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 4320001 samples --> skipped, already sampled at 100.0 Hz
# merging...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# slicing...
# 1 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c04108f60>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c061f4b38>}, 'twin': [UTCDateTime(2014, 5, 1, 0, 0), UTCDateTime(2014, 5, 1, 1, 0)], 'opath': 'out_archive/20140501T000000_20140501T010000'}
# 2 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c04115b38>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c0411db00>}, 'twin': [UTCDateTime(2014, 5, 1, 1, 0), UTCDateTime(2014, 5, 1, 2, 0)], 'opath': 'out_archive/20140501T010000_20140501T020000'}
# 3 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c04111d68>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c04111908>}, 'twin': [UTCDateTime(2014, 5, 1, 2, 0), UTCDateTime(2014, 5, 1, 3, 0)], 'opath': 'out_archive/20140501T020000_20140501T030000'}
# 4 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040c6a90>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c04115128>}, 'twin': [UTCDateTime(2014, 5, 1, 3, 0), UTCDateTime(2014, 5, 1, 4, 0)], 'opath': 'out_archive/20140501T030000_20140501T040000'}
# 5 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040c6f60>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040c6fd0>}, 'twin': [UTCDateTime(2014, 5, 1, 4, 0), UTCDateTime(2014, 5, 1, 5, 0)], 'opath': 'out_archive/20140501T040000_20140501T050000'}
# 6 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040d5278>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040c6908>}, 'twin': [UTCDateTime(2014, 5, 1, 5, 0), UTCDateTime(2014, 5, 1, 6, 0)], 'opath': 'out_archive/20140501T050000_20140501T060000'}
# 7 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040d58d0>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040d5940>}, 'twin': [UTCDateTime(2014, 5, 1, 6, 0), UTCDateTime(2014, 5, 1, 7, 0)], 'opath': 'out_archive/20140501T060000_20140501T070000'}
# 8 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040db048>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040d5208>}, 'twin': [UTCDateTime(2014, 5, 1, 7, 0), UTCDateTime(2014, 5, 1, 8, 0)], 'opath': 'out_archive/20140501T070000_20140501T080000'}
# 9 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040db710>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040db780>}, 'twin': [UTCDateTime(2014, 5, 1, 8, 0), UTCDateTime(2014, 5, 1, 9, 0)], 'opath': 'out_archive/20140501T080000_20140501T090000'}
# 10 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040dbe10>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040dbcc0>}, 'twin': [UTCDateTime(2014, 5, 1, 9, 0), UTCDateTime(2014, 5, 1, 10, 0)], 'opath': 'out_archive/20140501T090000_20140501T100000'}
# 11 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040e0550>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040dbe80>}, 'twin': [UTCDateTime(2014, 5, 1, 10, 0), UTCDateTime(2014, 5, 1, 11, 0)], 'opath': 'out_archive/20140501T100000_20140501T110000'}
# 12 {'st': {'PB01': <obspy.core.stream.Stream object at 0x7f7c040e0c50>, 'PB02': <obspy.core.stream.Stream object at 0x7f7c040e0cc0>}, 'twin': [UTCDateTime(2014, 5, 1, 11, 0), UTCDateTime(2014, 5, 1, 12, 0)], 'opath': 'out_archive/20140501T110000_20140501T120000'}

# %% [markdown]
# ## 3. Run phase detection and picking

# %%
# model
dpp_model = model.Model(verbose=False)
# dpp_model = model.Model(verbose=False, version_pick_P="20201002_2", version_pick_S="20201002_2")
#
# print(dpp_model.model_detection['best_model'].summary())
# print(dpp_model.model_picking_P['best_model'].summary())
# print(dpp_model.model_picking_S['best_model'].summary())

# %%
# run phase detection
dpp_model.run_detection(dpp_config, dpp_data, save_dets=False, save_data=False)
# Out:
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 28s 39ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-04-30T23:59:59.998391Z - 2014-05-01T00:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 23, s_picks = 12
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 35s 48ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-04-30T23:59:59.998393Z - 2014-05-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-04-30T23:59:59.998393Z - 2014-05-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-04-30T23:59:59.998393Z - 2014-05-01T00:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 12, s_picks = 11
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 37s 51ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T00:59:59.998393Z - 2014-05-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T00:59:59.998391Z - 2014-05-01T01:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T00:59:59.998393Z - 2014-05-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 25, s_picks = 19
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 40s 56ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T00:59:59.998393Z - 2014-05-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T00:59:59.998393Z - 2014-05-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T00:59:59.998393Z - 2014-05-01T01:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 21, s_picks = 21
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 39s 54ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T01:59:59.998393Z - 2014-05-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T01:59:59.998391Z - 2014-05-01T02:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T01:59:59.998393Z - 2014-05-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 18, s_picks = 6
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 38s 53ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T01:59:59.998393Z - 2014-05-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T01:59:59.998393Z - 2014-05-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T01:59:59.998393Z - 2014-05-01T02:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 13, s_picks = 6
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 41s 57ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T02:59:59.998393Z - 2014-05-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T02:59:59.998391Z - 2014-05-01T03:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T02:59:59.998393Z - 2014-05-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 14, s_picks = 4
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 39s 54ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T02:59:59.998393Z - 2014-05-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T02:59:59.998393Z - 2014-05-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T02:59:59.998393Z - 2014-05-01T03:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 7, s_picks = 3
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 39s 55ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T03:59:59.998393Z - 2014-05-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T03:59:59.998391Z - 2014-05-01T04:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T03:59:59.998393Z - 2014-05-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 21, s_picks = 14
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 32s 44ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T03:59:59.998393Z - 2014-05-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T03:59:59.998393Z - 2014-05-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T03:59:59.998393Z - 2014-05-01T04:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 19, s_picks = 10
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 40s 56ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T04:59:59.998393Z - 2014-05-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T04:59:59.998391Z - 2014-05-01T05:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T04:59:59.998393Z - 2014-05-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 19, s_picks = 10
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 38s 52ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T04:59:59.998393Z - 2014-05-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T04:59:59.998393Z - 2014-05-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T04:59:59.998393Z - 2014-05-01T05:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 8, s_picks = 7
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 34s 48ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T05:59:59.998393Z - 2014-05-01T06:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T05:59:59.998391Z - 2014-05-01T06:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T05:59:59.998393Z - 2014-05-01T06:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 21, s_picks = 10
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 36s 50ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T05:59:59.998393Z - 2014-05-01T06:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T05:59:59.998393Z - 2014-05-01T06:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T05:59:59.998393Z - 2014-05-01T06:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 8, s_picks = 5
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 37s 51ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T06:59:59.998393Z - 2014-05-01T07:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T06:59:59.998391Z - 2014-05-01T07:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T06:59:59.998393Z - 2014-05-01T07:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 18, s_picks = 13
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 38s 53ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T06:59:59.998393Z - 2014-05-01T07:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T06:59:59.998393Z - 2014-05-01T07:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T06:59:59.998393Z - 2014-05-01T07:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 14, s_picks = 8
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 43s 60ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T07:59:59.998393Z - 2014-05-01T08:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T07:59:59.998391Z - 2014-05-01T08:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T07:59:59.998393Z - 2014-05-01T08:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 9, s_picks = 6
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 36s 49ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T07:59:59.998393Z - 2014-05-01T08:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T07:59:59.998393Z - 2014-05-01T08:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T07:59:59.998393Z - 2014-05-01T08:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 8, s_picks = 4
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 34s 48ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T08:59:59.998393Z - 2014-05-01T09:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T08:59:59.998391Z - 2014-05-01T09:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T08:59:59.998393Z - 2014-05-01T09:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 20, s_picks = 10
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 30s 42ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T08:59:59.998393Z - 2014-05-01T09:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T08:59:59.998393Z - 2014-05-01T09:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T08:59:59.998393Z - 2014-05-01T09:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 14, s_picks = 9
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 32s 44ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T09:59:59.998393Z - 2014-05-01T10:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T09:59:59.998391Z - 2014-05-01T10:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T09:59:59.998393Z - 2014-05-01T10:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 11, s_picks = 5
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 29s 40ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T09:59:59.998393Z - 2014-05-01T10:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T09:59:59.998393Z - 2014-05-01T10:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T09:59:59.998393Z - 2014-05-01T10:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 7, s_picks = 5
# #
# Calculating predictions for stream: CX.PB01..HH?...
# strimming stream: 2, 2
# 720/720 [==============================] - 34s 47ms/step
# 3 Trace(s) in Stream:
# CX.PB01..HHE | 2014-05-01T10:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB01..HHN | 2014-05-01T10:59:59.998391Z - 2014-05-01T11:59:59.998391Z | 100.0 Hz, 360001 samples
# CX.PB01..HHZ | 2014-05-01T10:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 18, s_picks = 11
# #
# Calculating predictions for stream: CX.PB02..HH?...
# 720/720 [==============================] - 32s 44ms/step
# 3 Trace(s) in Stream:
# CX.PB02..HHE | 2014-05-01T10:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHN | 2014-05-01T10:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 360001 samples
# CX.PB02..HHZ | 2014-05-01T10:59:59.998393Z - 2014-05-01T11:59:59.998393Z | 100.0 Hz, 360001 samples
# p_picks = 17, s_picks = 11

# %%
# run phase picking
dpp_model.run_picking(dpp_config, dpp_data, save_plots=False, save_stats=True, save_picks=False)
# Out:
# #
# 1, 2014-05-01T00:00:00.000000Z, 2014-05-01T01:00:00.000000Z, PB01
# triggered picks (P, S): 23, 12
# selected picks (P, S): 21, 9
# #
# 1, 2014-05-01T00:00:00.000000Z, 2014-05-01T01:00:00.000000Z, PB02
# triggered picks (P, S): 12, 11
# selected picks (P, S): 8, 5
# #
# 2, 2014-05-01T01:00:00.000000Z, 2014-05-01T02:00:00.000000Z, PB01
# triggered picks (P, S): 25, 19
# selected picks (P, S): 21, 12
# #
# 2, 2014-05-01T01:00:00.000000Z, 2014-05-01T02:00:00.000000Z, PB02
# triggered picks (P, S): 21, 21
# selected picks (P, S): 18, 7
# #
# 3, 2014-05-01T02:00:00.000000Z, 2014-05-01T03:00:00.000000Z, PB01
# triggered picks (P, S): 18, 6
# selected picks (P, S): 16, 4
# #
# 3, 2014-05-01T02:00:00.000000Z, 2014-05-01T03:00:00.000000Z, PB02
# triggered picks (P, S): 13, 6
# selected picks (P, S): 10, 2
# #
# 4, 2014-05-01T03:00:00.000000Z, 2014-05-01T04:00:00.000000Z, PB01
# triggered picks (P, S): 14, 4
# selected picks (P, S): 13, 3
# #
# 4, 2014-05-01T03:00:00.000000Z, 2014-05-01T04:00:00.000000Z, PB02
# triggered picks (P, S): 7, 3
# selected picks (P, S): 7, 1
# #
# 5, 2014-05-01T04:00:00.000000Z, 2014-05-01T05:00:00.000000Z, PB01
# triggered picks (P, S): 21, 14
# selected picks (P, S): 20, 9
# #
# 5, 2014-05-01T04:00:00.000000Z, 2014-05-01T05:00:00.000000Z, PB02
# triggered picks (P, S): 19, 10
# selected picks (P, S): 17, 5
# #
# 6, 2014-05-01T05:00:00.000000Z, 2014-05-01T06:00:00.000000Z, PB01
# triggered picks (P, S): 19, 10
# selected picks (P, S): 18, 4
# #
# 6, 2014-05-01T05:00:00.000000Z, 2014-05-01T06:00:00.000000Z, PB02
# triggered picks (P, S): 8, 7
# selected picks (P, S): 7, 3
# #
# 7, 2014-05-01T06:00:00.000000Z, 2014-05-01T07:00:00.000000Z, PB01
# triggered picks (P, S): 21, 10
# selected picks (P, S): 18, 5
# #
# 7, 2014-05-01T06:00:00.000000Z, 2014-05-01T07:00:00.000000Z, PB02
# triggered picks (P, S): 8, 5
# selected picks (P, S): 6, 3
# #
# 8, 2014-05-01T07:00:00.000000Z, 2014-05-01T08:00:00.000000Z, PB01
# triggered picks (P, S): 18, 13
# selected picks (P, S): 16, 7
# #
# 8, 2014-05-01T07:00:00.000000Z, 2014-05-01T08:00:00.000000Z, PB02
# triggered picks (P, S): 14, 8
# selected picks (P, S): 10, 3
# #
# 9, 2014-05-01T08:00:00.000000Z, 2014-05-01T09:00:00.000000Z, PB01
# triggered picks (P, S): 9, 6
# selected picks (P, S): 9, 1
# #
# 9, 2014-05-01T08:00:00.000000Z, 2014-05-01T09:00:00.000000Z, PB02
# triggered picks (P, S): 8, 4
# selected picks (P, S): 8, 1
# #
# 10, 2014-05-01T09:00:00.000000Z, 2014-05-01T10:00:00.000000Z, PB01
# triggered picks (P, S): 20, 10
# selected picks (P, S): 19, 5
# #
# 10, 2014-05-01T09:00:00.000000Z, 2014-05-01T10:00:00.000000Z, PB02
# triggered picks (P, S): 14, 9
# selected picks (P, S): 12, 4
# #
# 11, 2014-05-01T10:00:00.000000Z, 2014-05-01T11:00:00.000000Z, PB01
# triggered picks (P, S): 11, 5
# selected picks (P, S): 10, 2
# #
# 11, 2014-05-01T10:00:00.000000Z, 2014-05-01T11:00:00.000000Z, PB02
# triggered picks (P, S): 7, 5
# selected picks (P, S): 5, 1
# #
# 12, 2014-05-01T11:00:00.000000Z, 2014-05-01T12:00:00.000000Z, PB01
# triggered picks (P, S): 18, 11
# selected picks (P, S): 14, 6
# #
# 12, 2014-05-01T11:00:00.000000Z, 2014-05-01T12:00:00.000000Z, PB02
# triggered picks (P, S): 17, 11
# selected picks (P, S): 12, 5

# %%
# plots
# util.plot_predicted_phases(dpp_config, dpp_data, dpp_model)
util.plot_predicted_phases(dpp_config, dpp_data, dpp_model, plot_probs=['P','S'], shift_probs=True)
# Out:
# creating plots...
# 1 PB01 Z 2014-04-30T23:59:59.998393Z 2014-05-01T00:59:59.998393Z
# 1 PB01 E 2014-04-30T23:59:59.998393Z 2014-05-01T00:59:59.998393Z
# 1 PB02 Z 2014-04-30T23:59:59.998393Z 2014-05-01T00:59:59.998393Z
# 1 PB02 E 2014-04-30T23:59:59.998393Z 2014-05-01T00:59:59.998393Z
# 2 PB01 Z 2014-05-01T00:59:59.998393Z 2014-05-01T01:59:59.998393Z
# 2 PB01 E 2014-05-01T00:59:59.998393Z 2014-05-01T01:59:59.998393Z
# 2 PB02 Z 2014-05-01T00:59:59.998393Z 2014-05-01T01:59:59.998393Z
# 2 PB02 E 2014-05-01T00:59:59.998393Z 2014-05-01T01:59:59.998393Z
# 3 PB01 Z 2014-05-01T01:59:59.998393Z 2014-05-01T02:59:59.998393Z
# 3 PB01 E 2014-05-01T01:59:59.998393Z 2014-05-01T02:59:59.998393Z
# 3 PB02 Z 2014-05-01T01:59:59.998393Z 2014-05-01T02:59:59.998393Z
# 3 PB02 E 2014-05-01T01:59:59.998393Z 2014-05-01T02:59:59.998393Z
# 4 PB01 Z 2014-05-01T02:59:59.998393Z 2014-05-01T03:59:59.998393Z
# 4 PB01 E 2014-05-01T02:59:59.998393Z 2014-05-01T03:59:59.998393Z
# 4 PB02 Z 2014-05-01T02:59:59.998393Z 2014-05-01T03:59:59.998393Z
# 4 PB02 E 2014-05-01T02:59:59.998393Z 2014-05-01T03:59:59.998393Z
# 5 PB01 Z 2014-05-01T03:59:59.998393Z 2014-05-01T04:59:59.998393Z
# 5 PB01 E 2014-05-01T03:59:59.998393Z 2014-05-01T04:59:59.998393Z
# 5 PB02 Z 2014-05-01T03:59:59.998393Z 2014-05-01T04:59:59.998393Z
# 5 PB02 E 2014-05-01T03:59:59.998393Z 2014-05-01T04:59:59.998393Z
# 6 PB01 Z 2014-05-01T04:59:59.998393Z 2014-05-01T05:59:59.998393Z
# 6 PB01 E 2014-05-01T04:59:59.998393Z 2014-05-01T05:59:59.998393Z
# 6 PB02 Z 2014-05-01T04:59:59.998393Z 2014-05-01T05:59:59.998393Z
# 6 PB02 E 2014-05-01T04:59:59.998393Z 2014-05-01T05:59:59.998393Z
# 7 PB01 Z 2014-05-01T05:59:59.998393Z 2014-05-01T06:59:59.998393Z
# 7 PB01 E 2014-05-01T05:59:59.998393Z 2014-05-01T06:59:59.998393Z
# 7 PB02 Z 2014-05-01T05:59:59.998393Z 2014-05-01T06:59:59.998393Z
# 7 PB02 E 2014-05-01T05:59:59.998393Z 2014-05-01T06:59:59.998393Z
# 8 PB01 Z 2014-05-01T06:59:59.998393Z 2014-05-01T07:59:59.998393Z
# 8 PB01 E 2014-05-01T06:59:59.998393Z 2014-05-01T07:59:59.998393Z
# 8 PB02 Z 2014-05-01T06:59:59.998393Z 2014-05-01T07:59:59.998393Z
# 8 PB02 E 2014-05-01T06:59:59.998393Z 2014-05-01T07:59:59.998393Z
# 9 PB01 Z 2014-05-01T07:59:59.998393Z 2014-05-01T08:59:59.998393Z
# 9 PB01 E 2014-05-01T07:59:59.998393Z 2014-05-01T08:59:59.998393Z
# 9 PB02 Z 2014-05-01T07:59:59.998393Z 2014-05-01T08:59:59.998393Z
# 9 PB02 E 2014-05-01T07:59:59.998393Z 2014-05-01T08:59:59.998393Z
# 10 PB01 Z 2014-05-01T08:59:59.998393Z 2014-05-01T09:59:59.998393Z
# 10 PB01 E 2014-05-01T08:59:59.998393Z 2014-05-01T09:59:59.998393Z
# 10 PB02 Z 2014-05-01T08:59:59.998393Z 2014-05-01T09:59:59.998393Z
# 10 PB02 E 2014-05-01T08:59:59.998393Z 2014-05-01T09:59:59.998393Z
# 11 PB01 Z 2014-05-01T09:59:59.998393Z 2014-05-01T10:59:59.998393Z
# 11 PB01 E 2014-05-01T09:59:59.998393Z 2014-05-01T10:59:59.998393Z
# 11 PB02 Z 2014-05-01T09:59:59.998393Z 2014-05-01T10:59:59.998393Z
# 11 PB02 E 2014-05-01T09:59:59.998393Z 2014-05-01T10:59:59.998393Z
# 12 PB01 Z 2014-05-01T10:59:59.998393Z 2014-05-01T11:59:59.998393Z
# 12 PB01 E 2014-05-01T10:59:59.998393Z 2014-05-01T11:59:59.998393Z
# 12 PB02 Z 2014-05-01T10:59:59.998393Z 2014-05-01T11:59:59.998393Z
# 12 PB02 E 2014-05-01T10:59:59.998393Z 2014-05-01T11:59:59.998393Z
